# %%
import pandas as pd 
import folium
import datetime

# %%
map_og= folium.Map(location=[34.416827, -119.703623])	
map_og
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_05ae94258d8db4e5fcdaeb05eca58ac2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_05ae94258d8db4e5fcdaeb05eca58ac2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_05ae94258d8db4e5fcdaeb05eca58ac2 = L.map(
#                 &quot;map_05ae94258d8db4e5fcdaeb05eca58ac2&quot;,
#                 {
#                     center: [34.416827, -119.703623],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc91dd0e6f2bb8c6f54dc10bdfe9a927 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_05ae94258d8db4e5fcdaeb05eca58ac2);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
well_locations = pd.read_csv("wells.csv")
well_locations = well_locations[["DECIMALLATITUDE", "DECIMALLONGITUDE", "PLANNEDUSEFORMERUSE", "DATEWORKENDED", "COLOR", "TOTALCOMPLETEDDEPTH"]]

# %%
well_locations_year = well_locations["DATEWORKENDED"]
well_locations['Year'] = pd.DatetimeIndex(well_locations["DATEWORKENDED"]).year
well_locations.head()
# Out:
#    DECIMALLATITUDE  DECIMALLONGITUDE    PLANNEDUSEFORMERUSE DATEWORKENDED  \
# 0        34.448134       -119.624654  Water Supply Domestic        2/3/15
# 1        34.452287       -119.561809  Water Supply Domestic       6/13/17
# 2        34.528970       -119.834360  Water Supply Domestic       6/14/13
# 3        34.428840       -119.645920  Water Supply Domestic       9/25/12
# 4        34.456200       -119.677600  Water Supply Domestic      12/13/16
#
#         COLOR  TOTALCOMPLETEDDEPTH  Year
# 0        pink                580.0  2015
# 1   darkgreen                888.0  2017
# 2      orange                487.0  2013
# 3       beige                580.0  2012
# 4  lightgreen                640.0  2016

# %%
map = folium.Map(location=[34.416827, -119.703623], tiles = "stamenwatercolor")	

my_list = ['TOTALCOMPLETEDDEPTH', 'Year']
for i in range(0,len(well_locations)):
   folium.Marker(
      location=[well_locations.iloc[i]['DECIMALLATITUDE'], well_locations.iloc[i]['DECIMALLONGITUDE']],
      popup = "Year Constructed: %s & Well Depth (ft): %s" % (well_locations.iloc[i]['Year'], well_locations.iloc[i]['TOTALCOMPLETEDDEPTH']),
      icon = folium.Icon(color = well_locations.iloc[i]['COLOR'], icon = "tint"),
   ).add_to(map)

map
# Out:
# /var/folders/yc/4xlp618d10g940lt269ldcnh0000gn/T/ipykernel_58215/4121786960.py:8: UserWarning: color argument of Icon should be one of: {'blue', 'cadetblue', 'pink', 'purple', 'darkblue', 'beige', 'lightred', 'darkpurple', 'lightblue', 'red', 'lightgreen', 'white', 'green', 'orange', 'lightgray', 'black', 'darkred', 'darkgreen', 'gray'}.
#   icon = folium.Icon(color = well_locations.iloc[i]['COLOR'], icon = "tint"),
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec6c7ab885027f96ae7402474092ff3c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec6c7ab885027f96ae7402474092ff3c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ec6c7ab885027f96ae7402474092ff3c = L.map(
#                 &quot;map_ec6c7ab885027f96ae7402474092ff3c&quot;,
#                 {
#                     center: [34.416827, -119.703623],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e03edef59427460abc6c944629e08eb4 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/watercolor/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ec6c7ab885027f96ae7402474092ff3c);
#
#
#             var marker_17c69ba7c295b6996486af86fdffa196 = L.marker(
#                 [34.4481344, -119.6246536],
#                 {}
#             ).addTo(map_ec6c7ab885027f96ae7402474092ff3c);
#
#
#             var icon_749a13397b502483d4a20c53e3d0e811 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;tint&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_17c69ba7c295b6996486af86fdffa196.setIcon(icon_749a13397b502483d4a20c53e3d0e811);
#
#
#         var popup_c271cc19c40319186bbf5c17a3c528d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_816dc371062aa42781bdff8c84b10d8b = $(`&lt;div id=&quot;html_816dc371062aa42781bdff8c84b10d8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Year Constructed: 2015 &amp; Well Depth (ft): 580.0&lt;/div&gt;`)[0];
#             popup_c271cc19c40319186bbf5c17a3c528d0.setContent(html_816dc371062aa42781bdff8c84b10d8b);
#
#
#         marker_17c69ba7c295b6996486af86fdffa196.bindPopup(popup_c271cc19c40319186bbf5c17a3c528d0)
#         ;
#
#
#
#
#             var marker_2901334fea4bffdfcd120ac97a382046 = L.marker(
#                 [34.452287, -119.561809],
#                 {}
#             ).addTo(map_ec6c7ab885027f96ae7402474092ff3c);
#
#
#             var icon_711df4f3d9a22fac907ca7cc6a75e412 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;tint&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2901334fea4bffdfcd120ac97a382046.setIcon(icon_711df4f3d9a22fac907ca7cc6a75e412);
#
#
#         var popup_5970ae8ce7960e1c56028dccc30f3d97 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_471a33dc74447cbb8a257c9516d18b71 = $(`&lt;div id=&quot;html_471a33dc74447cbb8a257c9516d18b71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Year Constructed: 2017 &amp; Well Depth (ft): 888.0&lt;/div&gt;`)[0];
#             popup_5970ae8ce7960e1c56028dccc30f3d97.setContent(html_471a33dc74447cbb8a257c9516d18b71);
#
#
#         marker_2901334fea4bffdfcd120ac97a382046.bindPopup(popup_5970ae8ce7960e1c56028dccc30f3d97)
#         ;
#
#
#
#
#             var marker_c1eab44543c07dca2c8898fc070e549f = L.marker(
#                 [34.52897, -119.83436],
#                 {}
#             ).addTo(map_ec6c7ab885027f96ae7402474092ff3c);
#
#
#             var icon_c6c92462ff6e094e21315eeefa5bb654 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;tint&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c1eab44543c07dca2c8898fc070e549f.setIcon(icon_c6c92462ff6e094e21315eeefa5bb654);
#
#
#         var popup_6dafd017bdf9538e02a1d63bdd09686d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1314ec395bcf13c9b2798c706987fee0 = $(`&lt;div id=&quot;html_1314ec395bcf13c9b2798c706987fee0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Year Constructed: 2013 &amp; Well Depth (ft): 487.0&lt;/div&gt;`)[0];
#             popup_6dafd017bdf9538e02a1d63bdd09686d.setContent(html_1314ec395bcf13c9b2798c706987fee0);
#
#
#         marker_c1eab44543c07dca2c8898fc070e549f.bindPopup(popup_6dafd017bdf9538e02a1d63bdd09686d)
#         ;
#
#
#
#
#             var marker_40a6eb7f5cbedf974a884cf55c7e5eca = L.marker(
#                 [34.42884, -119.64592],
#                 {}
#             ).addTo(map_ec6c7ab885027f96ae7402474092ff3c);
#
#
#             var icon_eb2fb8166d489ede9a3c8da63abf6a5f = L.AwesomeMarkers
